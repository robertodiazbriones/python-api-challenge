# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %%
#Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#set up lists to hold reponse info
City_name, Lat, Lng, Max_Tmp, Humidity, Cloudiness, Wind_Spd, Country, Date = [], [],[],[],[],[],[],[],[]
i,b=0,1

#Loop through each character
for city in cities:
    i=i+1
#Create search query, make request and store in json
    response = requests.get(query_url + city).json()
    
#Try to append data of interest to correesponding list
    try:
        City_name.append(response['name'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        Max_Tmp.append(response['main']['temp_max'])
        Humidity.append(response['main']['humidity'])
        Cloudiness.append(response['clouds']['all'])
        Wind_Spd.append(response['wind']['speed'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        
#Create test to print
        print(f"Processing Record {i} of set {b} | {city}")
        
#Handle exceptions for city not found
    except:
        print("City not found. Skipping...")
        pass
    if i >= 50:
        i=0
        b=b+1
# Out:
# City not found. Skipping...
# Processing Record 2 of set 1 | prince rupert
# Processing Record 3 of set 1 | nizhnevartovsk
# Processing Record 4 of set 1 | ushuaia
# Processing Record 5 of set 1 | kahului
# Processing Record 6 of set 1 | avarua
# Processing Record 7 of set 1 | gasa
# Processing Record 8 of set 1 | hithadhoo
# Processing Record 9 of set 1 | karratha
# Processing Record 10 of set 1 | mataura
# Processing Record 11 of set 1 | mattawa
# Processing Record 12 of set 1 | jamestown
# Processing Record 13 of set 1 | korla
# Processing Record 14 of set 1 | rikitea
# Processing Record 15 of set 1 | bluff
# Processing Record 16 of set 1 | quatre cocos
# Processing Record 17 of set 1 | puerto ayora
# Processing Record 18 of set 1 | axim
# Processing Record 19 of set 1 | khatanga
# Processing Record 20 of set 1 | east london
# Processing Record 21 of set 1 | longyearbyen
# Processing Record 22 of set 1 | nanortalik
# Processing Record 23 of set 1 | vaini
# City not found. Skipping...
# Processing Record 25 of set 1 | severo-kurilsk
# City not found. Skipping...
# Processing Record 27 of set 1 | kodiak
# Processing Record 28 of set 1 | traverse city
# Processing Record 29 of set 1 | bud
# Processing Record 30 of set 1 | jamame
# Processing Record 31 of set 1 | geraldton
# Processing Record 32 of set 1 | punta arenas
# City not found. Skipping...
# Processing Record 34 of set 1 | cape town
# Processing Record 35 of set 1 | provideniya
# Processing Record 36 of set 1 | mukhen
# Processing Record 37 of set 1 | college
# Processing Record 38 of set 1 | nokaneng
# Processing Record 39 of set 1 | abha
# Processing Record 40 of set 1 | winnemucca
# Processing Record 41 of set 1 | lagunas
# Processing Record 42 of set 1 | kapaa
# City not found. Skipping...
# Processing Record 44 of set 1 | kieta
# Processing Record 45 of set 1 | busselton
# City not found. Skipping...
# Processing Record 47 of set 1 | norman wells
# Processing Record 48 of set 1 | aklavik
# Processing Record 49 of set 1 | dikson
# Processing Record 50 of set 1 | ilulissat
# Processing Record 1 of set 2 | arraial do cabo
# Processing Record 2 of set 2 | banepa
# Processing Record 3 of set 2 | guerrero negro
# Processing Record 4 of set 2 | novopokrovka
# Processing Record 5 of set 2 | sao filipe
# Processing Record 6 of set 2 | berlevag
# Processing Record 7 of set 2 | mayo
# Processing Record 8 of set 2 | yonago
# Processing Record 9 of set 2 | cortez
# Processing Record 10 of set 2 | lebu
# Processing Record 11 of set 2 | qaanaaq
# Processing Record 12 of set 2 | saint-philippe
# Processing Record 13 of set 2 | namatanai
# Processing Record 14 of set 2 | ugoofaaru
# Processing Record 15 of set 2 | great bend
# Processing Record 16 of set 2 | kenai
# Processing Record 17 of set 2 | oskarshamn
# Processing Record 18 of set 2 | kaeo
# Processing Record 19 of set 2 | tuktoyaktuk
# Processing Record 20 of set 2 | hobart
# Processing Record 21 of set 2 | port elizabeth
# Processing Record 22 of set 2 | bowen
# Processing Record 23 of set 2 | mar del plata
# Processing Record 24 of set 2 | chokurdakh
# Processing Record 25 of set 2 | camacha
# Processing Record 26 of set 2 | new norfolk
# Processing Record 27 of set 2 | pevek
# Processing Record 28 of set 2 | wanaka
# Processing Record 29 of set 2 | dalvik
# City not found. Skipping...
# Processing Record 31 of set 2 | nikolskoye
# Processing Record 32 of set 2 | te anau
# Processing Record 33 of set 2 | hilo
# Processing Record 34 of set 2 | ucluelet
# Processing Record 35 of set 2 | albany
# Processing Record 36 of set 2 | los llanos de aridane
# Processing Record 37 of set 2 | itarema
# Processing Record 38 of set 2 | saldanha
# Processing Record 39 of set 2 | ruidoso
# Processing Record 40 of set 2 | bajos de haina
# Processing Record 41 of set 2 | port hawkesbury
# Processing Record 42 of set 2 | salinopolis
# Processing Record 43 of set 2 | le port
# City not found. Skipping...
# Processing Record 45 of set 2 | degtyarsk
# Processing Record 46 of set 2 | scarborough
# City not found. Skipping...
# Processing Record 48 of set 2 | broome
# Processing Record 49 of set 2 | barrow
# City not found. Skipping...
# Processing Record 1 of set 3 | shuyskoye
# Processing Record 2 of set 3 | vostok
# Processing Record 3 of set 3 | chase
# Processing Record 4 of set 3 | bethel
# Processing Record 5 of set 3 | bam
# Processing Record 6 of set 3 | faanui
# Processing Record 7 of set 3 | thompson
# Processing Record 8 of set 3 | kruisfontein
# Processing Record 9 of set 3 | jaisalmer
# Processing Record 10 of set 3 | taree
# Processing Record 11 of set 3 | provost
# Processing Record 12 of set 3 | sitka
# Processing Record 13 of set 3 | rawson
# Processing Record 14 of set 3 | port alfred
# Processing Record 15 of set 3 | bubaque
# Processing Record 16 of set 3 | atuona
# Processing Record 17 of set 3 | nakamura
# Processing Record 18 of set 3 | manzanillo
# Processing Record 19 of set 3 | samana
# Processing Record 20 of set 3 | camopi
# Processing Record 21 of set 3 | raga
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of set 3 | jalu
# Processing Record 25 of set 3 | kortrijk
# Processing Record 26 of set 3 | penukonda
# Processing Record 27 of set 3 | batagay
# City not found. Skipping...
# Processing Record 29 of set 3 | ostrovnoy
# Processing Record 30 of set 3 | georgetown
# Processing Record 31 of set 3 | lashio
# Processing Record 32 of set 3 | yellowknife
# Processing Record 33 of set 3 | salalah
# Processing Record 34 of set 3 | road town
# Processing Record 35 of set 3 | new richmond
# Processing Record 36 of set 3 | huanren
# Processing Record 37 of set 3 | auki
# Processing Record 38 of set 3 | ouahigouya
# Processing Record 39 of set 3 | great falls
# Processing Record 40 of set 3 | copiapo
# Processing Record 41 of set 3 | pemba
# City not found. Skipping...
# Processing Record 43 of set 3 | marawi
# Processing Record 44 of set 3 | san jose
# Processing Record 45 of set 3 | acarau
# Processing Record 46 of set 3 | bredasdorp
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of set 3 | maputo
# Processing Record 50 of set 3 | tasiilaq
# Processing Record 1 of set 4 | saint anthony
# Processing Record 2 of set 4 | beidao
# Processing Record 3 of set 4 | kalevala
# Processing Record 4 of set 4 | kaitangata
# Processing Record 5 of set 4 | pingzhuang
# Processing Record 6 of set 4 | castro
# Processing Record 7 of set 4 | miles city
# Processing Record 8 of set 4 | corcoran
# Processing Record 9 of set 4 | cabedelo
# Processing Record 10 of set 4 | hirara
# Processing Record 11 of set 4 | goderich
# Processing Record 12 of set 4 | ahipara
# Processing Record 13 of set 4 | carlisle
# Processing Record 14 of set 4 | tura
# Processing Record 15 of set 4 | maarianhamina
# Processing Record 16 of set 4 | coquimbo
# City not found. Skipping...
# Processing Record 18 of set 4 | zalantun
# Processing Record 19 of set 4 | torbay
# Processing Record 20 of set 4 | atar
# Processing Record 21 of set 4 | upington
# Processing Record 22 of set 4 | qaqortoq
# Processing Record 23 of set 4 | havoysund
# Processing Record 24 of set 4 | hami
# Processing Record 25 of set 4 | adeje
# Processing Record 26 of set 4 | carnarvon
# Processing Record 27 of set 4 | kapoeta
# City not found. Skipping...
# Processing Record 29 of set 4 | pangody
# Processing Record 30 of set 4 | chuy
# Processing Record 31 of set 4 | clyde river
# Processing Record 32 of set 4 | russell
# Processing Record 33 of set 4 | palmer
# Processing Record 34 of set 4 | pacific grove
# Processing Record 35 of set 4 | timra
# Processing Record 36 of set 4 | hermanus
# Processing Record 37 of set 4 | tsiroanomandidy
# City not found. Skipping...
# Processing Record 39 of set 4 | zabol
# Processing Record 40 of set 4 | rosetta
# Processing Record 41 of set 4 | upernavik
# Processing Record 42 of set 4 | leningradskiy
# Processing Record 43 of set 4 | ribeira grande
# Processing Record 44 of set 4 | cabo san lucas
# City not found. Skipping...
# Processing Record 46 of set 4 | mount gambier
# Processing Record 47 of set 4 | cherskiy
# Processing Record 48 of set 4 | khash
# Processing Record 49 of set 4 | great yarmouth
# Processing Record 50 of set 4 | bafata
# Processing Record 1 of set 5 | lompoc
# Processing Record 2 of set 5 | ponta do sol
# Processing Record 3 of set 5 | pocking
# Processing Record 4 of set 5 | cape canaveral
# Processing Record 5 of set 5 | christchurch
# Processing Record 6 of set 5 | montes altos
# Processing Record 7 of set 5 | tubuala
# Processing Record 8 of set 5 | cap-aux-meules
# Processing Record 9 of set 5 | winder
# Processing Record 10 of set 5 | victor harbor
# Processing Record 11 of set 5 | pisco
# Processing Record 12 of set 5 | lavumisa
# Processing Record 13 of set 5 | tigil
# Processing Record 14 of set 5 | mahabad
# Processing Record 15 of set 5 | saskylakh
# Processing Record 16 of set 5 | cordoba
# Processing Record 17 of set 5 | mahebourg
# Processing Record 18 of set 5 | san quintin
# Processing Record 19 of set 5 | narsaq
# Processing Record 20 of set 5 | jaffna
# City not found. Skipping...
# Processing Record 22 of set 5 | chicama
# Processing Record 23 of set 5 | esperance
# Processing Record 24 of set 5 | alofi
# Processing Record 25 of set 5 | toccoa
# Processing Record 26 of set 5 | salekhard
# Processing Record 27 of set 5 | bambous virieux
# Processing Record 28 of set 5 | jumla
# Processing Record 29 of set 5 | kurilsk
# Processing Record 30 of set 5 | isangel
# Processing Record 31 of set 5 | henties bay
# Processing Record 32 of set 5 | evensk
# Processing Record 33 of set 5 | lorengau
# Processing Record 34 of set 5 | lakitelek
# Processing Record 35 of set 5 | trapani
# City not found. Skipping...
# Processing Record 37 of set 5 | sept-iles
# Processing Record 38 of set 5 | shenzhen
# Processing Record 39 of set 5 | inirida
# Processing Record 40 of set 5 | parakai
# Processing Record 41 of set 5 | tual
# Processing Record 42 of set 5 | dunmore town
# City not found. Skipping...
# Processing Record 44 of set 5 | pochutla
# City not found. Skipping...
# Processing Record 46 of set 5 | denpasar
# Processing Record 47 of set 5 | roald
# Processing Record 48 of set 5 | mana
# Processing Record 49 of set 5 | calvinia
# Processing Record 50 of set 5 | tiksi
# Processing Record 1 of set 6 | asau
# Processing Record 2 of set 6 | martapura
# Processing Record 3 of set 6 | salamiyah
# Processing Record 4 of set 6 | luderitz
# Processing Record 5 of set 6 | surt
# Processing Record 6 of set 6 | ossora
# Processing Record 7 of set 6 | ryotsu
# Processing Record 8 of set 6 | piracuruca
# Processing Record 9 of set 6 | viedma
# Processing Record 10 of set 6 | hobyo
# Processing Record 11 of set 6 | zhezkazgan
# Processing Record 12 of set 6 | inhambane
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of set 6 | pecos
# Processing Record 16 of set 6 | saint-pierre
# Processing Record 17 of set 6 | ler
# Processing Record 18 of set 6 | aitape
# Processing Record 19 of set 6 | kushima
# City not found. Skipping...
# Processing Record 21 of set 6 | constitucion
# Processing Record 22 of set 6 | dunedin
# Processing Record 23 of set 6 | bouna
# Processing Record 24 of set 6 | maues
# Processing Record 25 of set 6 | coihaique
# Processing Record 26 of set 6 | souillac
# Processing Record 27 of set 6 | murray bridge
# Processing Record 28 of set 6 | teya
# City not found. Skipping...
# Processing Record 30 of set 6 | whyalla
# City not found. Skipping...
# Processing Record 32 of set 6 | husavik
# Processing Record 33 of set 6 | sandnessjoen
# Processing Record 34 of set 6 | akyab
# Processing Record 35 of set 6 | half moon bay
# Processing Record 36 of set 6 | katsuura
# Processing Record 37 of set 6 | yulara
# Processing Record 38 of set 6 | praya
# Processing Record 39 of set 6 | santa rosa
# Processing Record 40 of set 6 | vila franca do campo
# Processing Record 41 of set 6 | touros
# Processing Record 42 of set 6 | jiayuguan
# Processing Record 43 of set 6 | fort nelson
# Processing Record 44 of set 6 | mgachi
# Processing Record 45 of set 6 | puerto leguizamo
# City not found. Skipping...
# Processing Record 47 of set 6 | tabuk
# Processing Record 48 of set 6 | pitimbu
# Processing Record 49 of set 6 | dongkan
# Processing Record 50 of set 6 | dingle
# Processing Record 1 of set 7 | srednekolymsk
# Processing Record 2 of set 7 | egvekinot
# Processing Record 3 of set 7 | kavieng
# Processing Record 4 of set 7 | czluchow
# Processing Record 5 of set 7 | beringovskiy
# Processing Record 6 of set 7 | pangnirtung
# Processing Record 7 of set 7 | saint-joseph
# Processing Record 8 of set 7 | linhares
# Processing Record 9 of set 7 | zapolyarnyy
# Processing Record 10 of set 7 | cumpas
# Processing Record 11 of set 7 | nelson bay
# Processing Record 12 of set 7 | puerto escondido
# Processing Record 13 of set 7 | shache
# Processing Record 14 of set 7 | haines junction
# Processing Record 15 of set 7 | zepce
# Processing Record 16 of set 7 | anadyr
# Processing Record 17 of set 7 | conde
# Processing Record 18 of set 7 | moyale
# Processing Record 19 of set 7 | prince george
# Processing Record 20 of set 7 | omboue
# Processing Record 21 of set 7 | nampula
# Processing Record 22 of set 7 | coari
# Processing Record 23 of set 7 | tingo maria
# Processing Record 24 of set 7 | airai
# Processing Record 25 of set 7 | cayenne
# Processing Record 26 of set 7 | caravelas
# Processing Record 27 of set 7 | lahat
# City not found. Skipping...
# Processing Record 29 of set 7 | aksarka
# Processing Record 30 of set 7 | roma
# Processing Record 31 of set 7 | acapulco
# Processing Record 32 of set 7 | zhangjiakou
# Processing Record 33 of set 7 | pierre
# Processing Record 34 of set 7 | domoni
# Processing Record 35 of set 7 | yar-sale
# Processing Record 36 of set 7 | tagab
# Processing Record 37 of set 7 | jamshedpur
# Processing Record 38 of set 7 | coahuayana
# Processing Record 39 of set 7 | aykhal
# Processing Record 40 of set 7 | butaritari
# Processing Record 41 of set 7 | lavrentiya
# Processing Record 42 of set 7 | ginir
# Processing Record 43 of set 7 | emerald
# Processing Record 44 of set 7 | belyy yar
# Processing Record 45 of set 7 | bac lieu
# Processing Record 46 of set 7 | pangoa
# Processing Record 47 of set 7 | bengkulu
# Processing Record 48 of set 7 | deputatskiy
# Processing Record 49 of set 7 | ballina
# Processing Record 50 of set 7 | ruy barbosa
# Processing Record 1 of set 8 | morgan city
# Processing Record 2 of set 8 | shitanjing
# Processing Record 3 of set 8 | san patricio
# Processing Record 4 of set 8 | sambava
# Processing Record 5 of set 8 | parfenyevo
# Processing Record 6 of set 8 | ilhabela
# Processing Record 7 of set 8 | fortuna
# Processing Record 8 of set 8 | klaksvik
# Processing Record 9 of set 8 | zima
# Processing Record 10 of set 8 | port hedland
# Processing Record 11 of set 8 | puerto carreno
# City not found. Skipping...
# Processing Record 13 of set 8 | kirakira
# Processing Record 14 of set 8 | yatou
# Processing Record 15 of set 8 | chiang klang
# Processing Record 16 of set 8 | morbegno
# Processing Record 17 of set 8 | porto walter
# Processing Record 18 of set 8 | trimbak
# Processing Record 19 of set 8 | chandla
# Processing Record 20 of set 8 | arona
# Processing Record 21 of set 8 | port blair
# City not found. Skipping...
# Processing Record 23 of set 8 | progreso
# Processing Record 24 of set 8 | sihor
# Processing Record 25 of set 8 | victoria
# Processing Record 26 of set 8 | brookhaven
# Processing Record 27 of set 8 | herat
# Processing Record 28 of set 8 | high rock
# Processing Record 29 of set 8 | madingou
# Processing Record 30 of set 8 | arica
# Processing Record 31 of set 8 | kasulu
# Processing Record 32 of set 8 | la asuncion
# Processing Record 33 of set 8 | codrington
# Processing Record 34 of set 8 | faya
# Processing Record 35 of set 8 | chuchkovo
# Processing Record 36 of set 8 | leh
# City not found. Skipping...
# Processing Record 38 of set 8 | tromso
# Processing Record 39 of set 8 | portsmouth
# Processing Record 40 of set 8 | griffith
# Processing Record 41 of set 8 | nome
# Processing Record 42 of set 8 | turukhansk
# Processing Record 43 of set 8 | jibuti
# Processing Record 44 of set 8 | gongzhuling
# Processing Record 45 of set 8 | necochea
# Processing Record 46 of set 8 | kulhudhuffushi
# City not found. Skipping...
# Processing Record 48 of set 8 | broken hill
# Processing Record 49 of set 8 | rincon
# Processing Record 50 of set 8 | belen
# Processing Record 1 of set 9 | hualmay
# Processing Record 2 of set 9 | hasaki
# Processing Record 3 of set 9 | alexandria
# Processing Record 4 of set 9 | port-gentil
# Processing Record 5 of set 9 | olafsvik
# Processing Record 6 of set 9 | luanda
# Processing Record 7 of set 9 | ambon
# Processing Record 8 of set 9 | fredericksburg
# City not found. Skipping...
# Processing Record 10 of set 9 | biswan
# Processing Record 11 of set 9 | mount isa
# Processing Record 12 of set 9 | fort payne
# Processing Record 13 of set 9 | san cristobal
# Processing Record 14 of set 9 | sechura
# Processing Record 15 of set 9 | iqaluit
# Processing Record 16 of set 9 | praia da vitoria
# Processing Record 17 of set 9 | terney
# Processing Record 18 of set 9 | drakhtik
# Processing Record 19 of set 9 | natal
# Processing Record 20 of set 9 | katherine
# Processing Record 21 of set 9 | kedrovyy
# City not found. Skipping...
# Processing Record 23 of set 9 | paita
# Processing Record 24 of set 9 | lagoa
# Processing Record 25 of set 9 | morro bay
# Processing Record 26 of set 9 | kosonsoy
# Processing Record 27 of set 9 | plettenberg bay
# Processing Record 28 of set 9 | fuerte olimpo
# Processing Record 29 of set 9 | mantua
# Processing Record 30 of set 9 | black river
# Processing Record 31 of set 9 | grand gaube
# Processing Record 32 of set 9 | sobolevo
# Processing Record 33 of set 9 | tuatapere
# Processing Record 34 of set 9 | barda
# Processing Record 35 of set 9 | chichihualco
# Processing Record 36 of set 9 | crotone
# Processing Record 37 of set 9 | laguna
# Processing Record 38 of set 9 | coxim
# Processing Record 39 of set 9 | albury
# Processing Record 40 of set 9 | sokoni
# Processing Record 41 of set 9 | paamiut
# Processing Record 42 of set 9 | scottsbluff
# Processing Record 43 of set 9 | camana
# Processing Record 44 of set 9 | maragogi
# City not found. Skipping...
# Processing Record 46 of set 9 | dakar
# Processing Record 47 of set 9 | boca do acre
# Processing Record 48 of set 9 | puerto narino
# Processing Record 49 of set 9 | pucallpa
# Processing Record 50 of set 9 | arucas
# Processing Record 1 of set 10 | grindavik
# Processing Record 2 of set 10 | celestun
# Processing Record 3 of set 10 | nakhon phanom
# Processing Record 4 of set 10 | padre bernardo
# Processing Record 5 of set 10 | zeya
# Processing Record 6 of set 10 | bambanglipuro
# Processing Record 7 of set 10 | cockburn town
# Processing Record 8 of set 10 | kefamenanu
# Processing Record 9 of set 10 | beloha
# Processing Record 10 of set 10 | genhe
# Processing Record 11 of set 10 | tiarei
# Processing Record 12 of set 10 | grand-santi
# Processing Record 13 of set 10 | homer
# Processing Record 14 of set 10 | ballymena
# Processing Record 15 of set 10 | ca mau
# Processing Record 16 of set 10 | deming
# Processing Record 17 of set 10 | harlingen
# City not found. Skipping...
# Processing Record 19 of set 10 | huarmey
# Processing Record 20 of set 10 | binga
# Processing Record 21 of set 10 | wadi maliz
# Processing Record 22 of set 10 | mayana
# Processing Record 23 of set 10 | aksu
# Processing Record 24 of set 10 | moissala
# Processing Record 25 of set 10 | moberly
# Processing Record 26 of set 10 | cajimos
# Processing Record 27 of set 10 | seoul
# Processing Record 28 of set 10 | portland
# Processing Record 29 of set 10 | the valley
# City not found. Skipping...
# Processing Record 31 of set 10 | hay river
# Processing Record 32 of set 10 | neyshabur
# City not found. Skipping...
# Processing Record 34 of set 10 | licata
# City not found. Skipping...
# Processing Record 36 of set 10 | peniche
# City not found. Skipping...
# Processing Record 38 of set 10 | konstantinovka
# Processing Record 39 of set 10 | gharghoda
# City not found. Skipping...
# Processing Record 41 of set 10 | rzhyshchiv
# Processing Record 42 of set 10 | zhangye
# Processing Record 43 of set 10 | warmbad
# Processing Record 44 of set 10 | maltahohe
# Processing Record 45 of set 10 | tolmachevo
# Processing Record 46 of set 10 | vilhena
# Processing Record 47 of set 10 | vallenar
# Processing Record 48 of set 10 | usinsk
# City not found. Skipping...
# Processing Record 50 of set 10 | singapore
# City not found. Skipping...
# Processing Record 2 of set 11 | bauchi
# Processing Record 3 of set 11 | rovaniemi
# Processing Record 4 of set 11 | kampot
# Processing Record 5 of set 11 | duluth
# City not found. Skipping...
# Processing Record 7 of set 11 | pemangkat
# Processing Record 8 of set 11 | desna
# Processing Record 9 of set 11 | pafos
# Processing Record 10 of set 11 | talnakh
# Processing Record 11 of set 11 | sinjai
# Processing Record 12 of set 11 | honningsvag
# Processing Record 13 of set 11 | san rafael
# Processing Record 14 of set 11 | lastoursville
# Processing Record 15 of set 11 | oktyabrskoye
# Processing Record 16 of set 11 | erenhot
# Processing Record 17 of set 11 | leshukonskoye
# Processing Record 18 of set 11 | pueblo nuevo
# Processing Record 19 of set 11 | sakti
# Processing Record 20 of set 11 | lata
# Processing Record 21 of set 11 | indianola
# Processing Record 22 of set 11 | ust-nera
# Processing Record 23 of set 11 | morros
# Processing Record 24 of set 11 | sorland
# Processing Record 25 of set 11 | okhotsk
# Processing Record 26 of set 11 | kautokeino
# Processing Record 27 of set 11 | nemuro
# Processing Record 28 of set 11 | kloulklubed
# Processing Record 29 of set 11 | ciudad guayana
# Processing Record 30 of set 11 | semey
# Processing Record 31 of set 11 | orotukan
# Processing Record 32 of set 11 | vestmannaeyjar
# Processing Record 33 of set 11 | jacareacanga
# Processing Record 34 of set 11 | vila velha
# Processing Record 35 of set 11 | ustrzyki dolne
# City not found. Skipping...
# Processing Record 37 of set 11 | kaseda
# Processing Record 38 of set 11 | rawah
# Processing Record 39 of set 11 | noyon
# Processing Record 40 of set 11 | berezovyy
# Processing Record 41 of set 11 | mustasaari
# Processing Record 42 of set 11 | dalby
# Processing Record 43 of set 11 | bichis
# Processing Record 44 of set 11 | aljezur
# Processing Record 45 of set 11 | turka
# Processing Record 46 of set 11 | meulaboh
# Processing Record 47 of set 11 | duku
# Processing Record 48 of set 11 | houma
# Processing Record 49 of set 11 | port hardy
# Processing Record 50 of set 11 | bundaberg
# Processing Record 1 of set 12 | makakilo city
# Processing Record 2 of set 12 | sehithwa
# Processing Record 3 of set 12 | kalabo
# Processing Record 4 of set 12 | mae sot
# Processing Record 5 of set 12 | oxford
# Processing Record 6 of set 12 | paka
# Processing Record 7 of set 12 | xuddur
# Processing Record 8 of set 12 | sao felix do xingu
# Processing Record 9 of set 12 | winslow
# Processing Record 10 of set 12 | stokmarknes
# Processing Record 11 of set 12 | nouadhibou
# City not found. Skipping...
# Processing Record 13 of set 12 | kawalu
# Processing Record 14 of set 12 | yarada
# Processing Record 15 of set 12 | elizabeth city
# Processing Record 16 of set 12 | araguacu
# Processing Record 17 of set 12 | muli
# Processing Record 18 of set 12 | weihe
# Processing Record 19 of set 12 | camocim
# Processing Record 20 of set 12 | zlitan
# Processing Record 21 of set 12 | hambantota
# Processing Record 22 of set 12 | port lincoln
# Processing Record 23 of set 12 | velur
# Processing Record 24 of set 12 | meybod
# Processing Record 25 of set 12 | atherton
# Processing Record 26 of set 12 | georgiyevka
# Processing Record 27 of set 12 | borogontsy
# Processing Record 28 of set 12 | ravar
# Processing Record 29 of set 12 | flinders
# City not found. Skipping...
# Processing Record 31 of set 12 | yeppoon
# Processing Record 32 of set 12 | soyo
# Processing Record 33 of set 12 | hovd
# Processing Record 34 of set 12 | uitenhage
# Processing Record 35 of set 12 | tarata
# Processing Record 36 of set 12 | desdunes
# Processing Record 37 of set 12 | wattegama
# City not found. Skipping...
# Processing Record 39 of set 12 | tomatlan
# Processing Record 40 of set 12 | guaruja
# City not found. Skipping...
# Processing Record 42 of set 12 | atbasar
# Processing Record 43 of set 12 | rameswaram
# Processing Record 44 of set 12 | galle
# Processing Record 45 of set 12 | vredendal
# Processing Record 46 of set 12 | svetlogorsk
# Processing Record 47 of set 12 | songkhla
# Processing Record 48 of set 12 | marsa matruh
# Processing Record 49 of set 12 | kodinsk
# Processing Record 50 of set 12 | buala
# Processing Record 1 of set 13 | vanimo
# Processing Record 2 of set 13 | kuusamo
# Processing Record 3 of set 13 | wajir
# Processing Record 4 of set 13 | rio grande
# Processing Record 5 of set 13 | royan
# Processing Record 6 of set 13 | ulladulla
# Processing Record 7 of set 13 | milkovo
# City not found. Skipping...
# Processing Record 9 of set 13 | ahuimanu
# Processing Record 10 of set 13 | bandarbeyla
# Processing Record 11 of set 13 | tsabong
# Processing Record 12 of set 13 | molchanovo
# Processing Record 13 of set 13 | abu samrah
# Processing Record 14 of set 13 | namibe
# Processing Record 15 of set 13 | bredy
# Processing Record 16 of set 13 | najran

# %%
#Create dictionary with lists 
Weather_dict={
    "City":City_name,
    "Lat":Lat,
    "Lng":Lng,
    "Max Temp":Max_Tmp,
    "Humidity":Humidity,
    "Cloudiness":Cloudiness,
    "Wind Speed":Wind_Spd,
    "Country":Country,
    "Date":Date
}

#Create Data Frame and display
weather_df=pd.DataFrame(Weather_dict)
weather_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Prince Rupert  54.3161 -130.3201     42.80        87          90
# 1    Nizhnevartovsk  60.9344   76.5531    -11.20        84          90
# 2           Ushuaia -54.8000  -68.3000     44.60        87          40
# 3           Kahului  20.8947 -156.4700     75.20        78          75
# 4            Avarua -21.2078 -159.7750     84.20        61          20
# ..              ...      ...       ...       ...       ...         ...
# 558      Molchanovo  57.5817   83.7692     -1.05        93         100
# 559      Abu Samrah  35.3029   37.1841     47.70        51           0
# 560      Mossamedes -15.1961   12.1522     69.06        75          46
# 561           Bredy  52.4153   60.3411     18.75        97         100
# 562          Najrān  17.4924   44.1277     44.60        42           0
#
#      Wind Speed Country        Date
# 0         14.97      CA  1610249040
# 1          2.24      RU  1610248993
# 2         19.57      AR  1610248861
# 3          6.91      US  1610248866
# 4          9.22      CK  1610249040
# ..          ...     ...         ...
# 558        6.20      RU  1610249109
# 559        5.03      SY  1610249109
# 560        2.80      AO  1610249109
# 561        9.57      RU  1610249109
# 562        0.81      SA  1610249110
#
# [563 rows x 9 columns]

# %%
#display descriptive statistics
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  563.000000  563.000000  563.000000  563.000000  563.000000  563.000000
# mean    19.652224   16.472594   49.246004   74.028419   52.930728    7.837975
# std     33.204171   91.580920   31.159513   18.572238   39.955097    5.987901
# min    -54.800000 -179.166700  -35.120000    9.000000    0.000000    0.490000
# 25%     -7.426150  -66.889950   28.400000   65.000000    5.000000    3.440000
# 50%     22.890900   22.266700   59.380000   78.000000   64.000000    6.200000
# 75%     46.459450   93.175000   75.200000   87.000000   90.500000   10.360000
# max     78.218600  179.316700  106.270000  100.000000  100.000000   38.210000
#
#                Date
# count  5.630000e+02
# mean   1.610249e+09
# std    6.138435e+01
# min    1.610249e+09
# 25%    1.610249e+09
# 50%    1.610249e+09
# 75%    1.610249e+09
# max    1.610249e+09

# %%
#export data frame to csv file
weather_df.to_csv(output_data_file, index=False)

# %%
#filter cities with humidity bigger than 100
filt=(weather_df['Humidity']>100)
weather_df[filt]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#filter cities with humidity of 100
#---I filtered Humidity==100 just for practice
filt=(weather_df['Humidity']==100)
weather_df[filt]
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 100         Provost  52.3501 -110.2683     15.80       100          75
# 178  Great Yarmouth  52.6083    1.7305     30.99       100          90
# 212       Lakitelek  46.8760   19.9950     28.40       100          90
# 226            Asău  46.4333   26.4000     30.20       100          75
# 238           Pecos  31.4229 -103.4932     37.40       100          90
# 284           Žepče  44.4267   18.0378     30.20       100          90
# 294         Cayenne   4.9333  -52.3333     77.00       100          75
# 301          Pierre  44.3683 -100.3510     34.00       100         100
# 347          Kasulu  -4.5767   30.1025     68.00       100          75
# 354      Portsmouth  50.7990   -1.0913     33.01       100           0
# 364           Belen  36.4891   36.2233     37.40       100          75
# 409   Puerto Nariño  -3.7703  -70.3831     75.20       100          20
# 454       Singapore   1.2897  103.8501     75.20       100          90
# 460           Desna  50.9273   30.7605     33.01       100          93
# 490           Noyon  49.5833    3.0000     30.99       100          90
# 506          Oxford  51.7522   -1.2560     30.20       100          90
#
#      Wind Speed Country        Date
# 100        3.44      CA  1610249052
# 178       11.77      GB  1610249061
# 212        4.61      HU  1610249065
# 226        0.54      RO  1610249060
# 238        5.75      US  1610249068
# 284        2.30      BA  1610248862
# 294        3.44      GF  1610249075
# 301        4.00      US  1610248913
# 347        2.30      TZ  1610249081
# 354        6.85      GB  1610249082
# 364        4.61      TR  1610249083
# 409        2.30      CO  1610249089
# 454        8.05      SG  1610249094
# 460        8.95      UA  1610249095
# 490        1.14      FR  1610249099
# 506        5.75      GB  1610248961

# %%
#  Get the indices of cities that have humidity over 100%.
#---I filtered Humidity==100 just for practice
equal_100=weather_df.index[filt]
equal_100=equal_100.tolist()
equal_100
# Out:
# [100,
#  178,
#  212,
#  226,
#  238,
#  284,
#  294,
#  301,
#  347,
#  354,
#  364,
#  409,
#  454,
#  460,
#  490,
#  506]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#---I filtered Humidity==100 just for practice
Cleaned_weather_df=weather_df.drop(equal_100)

# %%
# I checked that all indexes with Humidity==100 were dropped
filt=(Cleaned_weather_df['Humidity']==100)
Cleaned_weather_df[filt]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Create a new column to display date with a different format
#---I filtered Humidity==100 just for practice
Cleaned_weather_df['Date_only']=pd.to_datetime(Cleaned_weather_df['Date'],unit='s')
Cleaned_weather_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Prince Rupert  54.3161 -130.3201     42.80        87          90
# 1    Nizhnevartovsk  60.9344   76.5531    -11.20        84          90
# 2           Ushuaia -54.8000  -68.3000     44.60        87          40
# 3           Kahului  20.8947 -156.4700     75.20        78          75
# 4            Avarua -21.2078 -159.7750     84.20        61          20
# ..              ...      ...       ...       ...       ...         ...
# 558      Molchanovo  57.5817   83.7692     -1.05        93         100
# 559      Abu Samrah  35.3029   37.1841     47.70        51           0
# 560      Mossamedes -15.1961   12.1522     69.06        75          46
# 561           Bredy  52.4153   60.3411     18.75        97         100
# 562          Najrān  17.4924   44.1277     44.60        42           0
#
#      Wind Speed Country        Date           Date_only
# 0         14.97      CA  1610249040 2021-01-10 03:24:00
# 1          2.24      RU  1610248993 2021-01-10 03:23:13
# 2         19.57      AR  1610248861 2021-01-10 03:21:01
# 3          6.91      US  1610248866 2021-01-10 03:21:06
# 4          9.22      CK  1610249040 2021-01-10 03:24:00
# ..          ...     ...         ...                 ...
# 558        6.20      RU  1610249109 2021-01-10 03:25:09
# 559        5.03      SY  1610249109 2021-01-10 03:25:09
# 560        2.80      AO  1610249109 2021-01-10 03:25:09
# 561        9.57      RU  1610249109 2021-01-10 03:25:09
# 562        0.81      SA  1610249110 2021-01-10 03:25:10
#
# [547 rows x 10 columns]

# %%
#Get the date when data was requested
Date=Cleaned_weather_df['Date_only'].values[0]
Date=str(Date)
Date=Date[0:10]
print(Date)
# Out:
# 2021-01-10

# %%
#Scatter Plot Latitud vs Max Temp

#Values
x_values = weather_df['Lat']
y_values = weather_df['Max Temp']

#Plotting values
plt.scatter(x_values,y_values, edgecolors='black')

#Adding  Labels
plt.xlabel('Latitud')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs Max Temperature('+Date+')')

#Grid ON
plt.grid()

#Display plot
plt.show()

#This plot shows the relationship between latitud and Temp as we can see as the latitude incre so the temp decrease

# %%
#Scatter Plot Latitud vs Cloudiness

#Values
x_values = weather_df['Lat']
y_values = weather_df['Cloudiness']

#Plotting values
plt.scatter(x_values,y_values, edgecolors='black')

#Adding  Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs Cloudiness('+Date+')')

#Grid ON
plt.grid()

#Display plot
plt.show()

#No correlation between latitude and  Cloudiness dots are all over the plot

# %%
#Scatter Plot Latitud vs wind Speed

#Values
x_values = weather_df['Lat']
y_values = weather_df['Wind Speed']

#Plotting values
plt.scatter(x_values,y_values, edgecolors='black')

#Adding  Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs Wind Speed(mph) ('+Date+')')

#Grid ON
plt.grid()

#Display plot
plt.show()

#No much corerelation between Latitude and Wind Speed

# %%
#Get all cities of the northern hemisphere
filt=(weather_df['Lat']>0)
North_Hemisphere_df=weather_df[filt]
North_Hemisphere_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Prince Rupert  54.3161 -130.3201     42.80        87          90
# 1    Nizhnevartovsk  60.9344   76.5531    -11.20        84          90
# 3           Kahului  20.8947 -156.4700     75.20        78          75
# 5              Gaza  31.5000   34.4667     57.00        82           0
# 9           Mattawa  46.7379 -119.9028     37.40        93          90
# ..              ...      ...       ...       ...       ...         ...
# 556     Bandarbeyla   9.4942   50.8122     71.83        72          95
# 558      Molchanovo  57.5817   83.7692     -1.05        93         100
# 559      Abu Samrah  35.3029   37.1841     47.70        51           0
# 561           Bredy  52.4153   60.3411     18.75        97         100
# 562          Najrān  17.4924   44.1277     44.60        42           0
#
#      Wind Speed Country        Date
# 0         14.97      CA  1610249040
# 1          2.24      RU  1610248993
# 3          6.91      US  1610248866
# 5          3.44      PS  1610249040
# 9          3.44      US  1610249041
# ..          ...     ...         ...
# 556       21.30      SO  1610249109
# 558        6.20      RU  1610249109
# 559        5.03      SY  1610249109
# 561        9.57      RU  1610249109
# 562        0.81      SA  1610249110
#
# [381 rows x 9 columns]

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = North_Hemisphere_df['Lat']
y_values = North_Hemisphere_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp(F)')
plt.title('Northern Hemisphere - City Latitud vs Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7475334105071025

# %%
#Get all cities of the southern hemisphere
filt=(weather_df['Lat']<0)
South_Hemisphere_df=weather_df[filt]
South_Hemisphere_df
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 2       Ushuaia -54.8000  -68.3000     44.60        87          40
# 4        Avarua -21.2078 -159.7750     84.20        61          20
# 6     Hithadhoo  -0.6000   73.0833     81.16        71         100
# 7      Karratha -20.7377  116.8463    106.27        16           7
# 8       Mataura -46.1927  168.8643     64.00        69          95
# ..          ...      ...       ...       ...       ...         ...
# 548      Vanimo  -2.6741  141.3028     84.74        70         100
# 551  Rio Grande -32.0350  -52.0986     73.36        86          78
# 553   Ulladulla -35.3500  150.4667     82.40        47          26
# 557     Tsabong -26.0217   22.4010     78.24        54          97
# 560  Mossamedes -15.1961   12.1522     69.06        75          46
#
#      Wind Speed Country        Date
# 2         19.57      AR  1610248861
# 4          9.22      CK  1610249040
# 6         11.36      MV  1610249040
# 7         14.41      AU  1610249040
# 8         20.00      NZ  1610249041
# ..          ...     ...         ...
# 548        3.02      PG  1610249108
# 551       16.33      BR  1610249108
# 553       10.36      AU  1610249108
# 557        6.02      BW  1610249109
# 560        2.80      AO  1610249109
#
# [182 rows x 9 columns]

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = South_Hemisphere_df['Lat']
y_values = South_Hemisphere_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp(F)')
plt.title('Southern Hemisphere - City Latitud vs Max Temp(F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.12646736556939372

# %%
#As we can see in both plots temp increase as we moved to the Equator, as we know because the curvature of the Earth we get more direct energy from the sun around the equator causing higuer temps

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = North_Hemisphere_df['Lat']
y_values = North_Hemisphere_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitud')
plt.ylabel('Humidity(%)')
plt.title('Northern Hemisphere - City Latitud vs Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.08714939396494899

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = South_Hemisphere_df['Lat']
y_values = South_Hemisphere_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitud')
plt.ylabel('Humidity(%)')
plt.title('Southern Hemisphere - City Latitud vs Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.1428580733028494

# %%
#With a small relathionship humidity increase in both hemisphere as we move to the north

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = North_Hemisphere_df['Lat']
y_values = North_Hemisphere_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitud')
plt.ylabel('Cloudiness(%)')
plt.title('Northern Hemisphere - City Latitud vs Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.014087231789442331

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = South_Hemisphere_df['Lat']
y_values = South_Hemisphere_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitud')
plt.ylabel('Cloudiness(%)')
plt.title('Southern Hemisphere - City Latitud vs Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.016790882626476118

# %%
#I would say humidity is close related with cloudiness both conditions show the same relationship pattern

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = North_Hemisphere_df['Lat']
y_values = North_Hemisphere_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitud')
plt.ylabel('Wind Speed(mph)')
plt.title('Northern Hemisphere - City Latitud vs Wind Speed(mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00995440919953691

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = South_Hemisphere_df['Lat']
y_values = South_Hemisphere_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitud')
plt.ylabel('Wind Speed(mph)')
plt.title('Southern Hemisphere - City Latitud vs Wind Speed(mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.17202874286057002

# %%
# Wind Speed seems doesnt change a lot due the altitud still wind speed is higuer on the south pole vs the north pole
