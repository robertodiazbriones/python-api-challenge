# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %%
#Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#set up lists to hold reponse info
City_name, Lat, Lng, Max_Tmp, Humidity, Cloudiness, Wind_Spd, Country, Date = [], [],[],[],[],[],[],[],[]
i,b=0,1

#Loop through each character
for city in cities:
    i=i+1
#Create search query, make request and store in json
    response = requests.get(query_url + city).json()
    
#Try to append data of interest to correesponding list
    try:
        City_name.append(response['name'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        Max_Tmp.append(response['main']['temp_max'])
        Humidity.append(response['main']['humidity'])
        Cloudiness.append(response['clouds']['all'])
        Wind_Spd.append(response['wind']['speed'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        
#Create test to print
        print(f"Processing Record {i} of set {b} | {city}")
        
#Handle exceptions for city not found
    except:
        print("City not found. Skipping...")
        pass
    if i >= 50:
        i=0
        b=b+1
# Out:
# Processing Record 1 of set 1 | isla vista
# Processing Record 2 of set 1 | hithadhoo
# City not found. Skipping...
# Processing Record 4 of set 1 | tefe
# Processing Record 5 of set 1 | tasiilaq
# Processing Record 6 of set 1 | kutum
# Processing Record 7 of set 1 | dwarka
# Processing Record 8 of set 1 | jamestown
# Processing Record 9 of set 1 | mancora
# Processing Record 10 of set 1 | bosaso
# Processing Record 11 of set 1 | lasa
# Processing Record 12 of set 1 | punta arenas
# Processing Record 13 of set 1 | cape town
# Processing Record 14 of set 1 | pisco
# Processing Record 15 of set 1 | arraial do cabo
# Processing Record 16 of set 1 | ushuaia
# Processing Record 17 of set 1 | qaqortoq
# Processing Record 18 of set 1 | atuona
# Processing Record 19 of set 1 | kon tum
# Processing Record 20 of set 1 | tuatapere
# City not found. Skipping...
# Processing Record 22 of set 1 | hermanus
# Processing Record 23 of set 1 | lebu
# Processing Record 24 of set 1 | yichang
# Processing Record 25 of set 1 | bluff
# Processing Record 26 of set 1 | hobart
# City not found. Skipping...
# Processing Record 28 of set 1 | tabou
# Processing Record 29 of set 1 | georgetown
# Processing Record 30 of set 1 | clyde river
# City not found. Skipping...
# Processing Record 32 of set 1 | pitimbu
# Processing Record 33 of set 1 | antofagasta
# Processing Record 34 of set 1 | vaini
# City not found. Skipping...
# Processing Record 36 of set 1 | mar del plata
# Processing Record 37 of set 1 | kapaa
# Processing Record 38 of set 1 | aljezur
# Processing Record 39 of set 1 | hilo
# Processing Record 40 of set 1 | san patricio
# Processing Record 41 of set 1 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 43 of set 1 | caravelas
# Processing Record 44 of set 1 | albany
# Processing Record 45 of set 1 | tacoronte
# Processing Record 46 of set 1 | shache
# Processing Record 47 of set 1 | helena
# Processing Record 48 of set 1 | tame
# Processing Record 49 of set 1 | teya
# Processing Record 50 of set 1 | palu
# Processing Record 1 of set 2 | avarua
# Processing Record 2 of set 2 | bengkulu
# Processing Record 3 of set 2 | saskylakh
# Processing Record 4 of set 2 | cao bang
# Processing Record 5 of set 2 | butaritari
# Processing Record 6 of set 2 | zhigansk
# Processing Record 7 of set 2 | touros
# Processing Record 8 of set 2 | cherskiy
# Processing Record 9 of set 2 | chiari
# Processing Record 10 of set 2 | mahebourg
# Processing Record 11 of set 2 | iqaluit
# Processing Record 12 of set 2 | thompson
# Processing Record 13 of set 2 | dunedin
# City not found. Skipping...
# Processing Record 15 of set 2 | yumen
# City not found. Skipping...
# Processing Record 17 of set 2 | bredasdorp
# Processing Record 18 of set 2 | catamarca
# City not found. Skipping...
# Processing Record 20 of set 2 | esperance
# Processing Record 21 of set 2 | san carlos de bariloche
# Processing Record 22 of set 2 | tazovskiy
# Processing Record 23 of set 2 | havelock
# Processing Record 24 of set 2 | faya
# Processing Record 25 of set 2 | norman wells
# Processing Record 26 of set 2 | uribia
# City not found. Skipping...
# Processing Record 28 of set 2 | sao joao da barra
# Processing Record 29 of set 2 | sebezh
# Processing Record 30 of set 2 | bismarck
# Processing Record 31 of set 2 | nikolskoye
# Processing Record 32 of set 2 | elizabeth city
# Processing Record 33 of set 2 | mataura
# Processing Record 34 of set 2 | braintree
# Processing Record 35 of set 2 | flinders
# Processing Record 36 of set 2 | vestmanna
# Processing Record 37 of set 2 | araouane
# Processing Record 38 of set 2 | misratah
# Processing Record 39 of set 2 | dikson
# Processing Record 40 of set 2 | saint-joseph
# Processing Record 41 of set 2 | rikitea
# Processing Record 42 of set 2 | abnub
# Processing Record 43 of set 2 | bambous virieux
# Processing Record 44 of set 2 | klaksvik
# Processing Record 45 of set 2 | mocuba
# Processing Record 46 of set 2 | coahuayana
# Processing Record 47 of set 2 | nioro
# City not found. Skipping...
# Processing Record 49 of set 2 | okha
# Processing Record 50 of set 2 | barcelos
# Processing Record 1 of set 3 | emerald
# Processing Record 2 of set 3 | vangaindrano
# City not found. Skipping...
# Processing Record 4 of set 3 | te anau
# Processing Record 5 of set 3 | saint-philippe
# Processing Record 6 of set 3 | east london
# Processing Record 7 of set 3 | kudahuvadhoo
# Processing Record 8 of set 3 | matagami
# Processing Record 9 of set 3 | norrtalje
# Processing Record 10 of set 3 | kavaratti
# Processing Record 11 of set 3 | constitucion
# Processing Record 12 of set 3 | vestmannaeyjar
# Processing Record 13 of set 3 | gat
# Processing Record 14 of set 3 | port elizabeth
# Processing Record 15 of set 3 | labuan
# Processing Record 16 of set 3 | chuy
# Processing Record 17 of set 3 | taoudenni
# Processing Record 18 of set 3 | chaplynka
# Processing Record 19 of set 3 | namibe
# Processing Record 20 of set 3 | ostrovnoy
# Processing Record 21 of set 3 | itarema
# Processing Record 22 of set 3 | hami
# Processing Record 23 of set 3 | upernavik
# Processing Record 24 of set 3 | labuhan
# Processing Record 25 of set 3 | rawson
# Processing Record 26 of set 3 | los llanos de aridane
# Processing Record 27 of set 3 | karratha
# Processing Record 28 of set 3 | gualeguaychu
# Processing Record 29 of set 3 | viedma
# Processing Record 30 of set 3 | north platte
# Processing Record 31 of set 3 | victoria
# Processing Record 32 of set 3 | zeya
# Processing Record 33 of set 3 | longyearbyen
# Processing Record 34 of set 3 | carnarvon
# Processing Record 35 of set 3 | saint-francois
# Processing Record 36 of set 3 | cumbitara
# Processing Record 37 of set 3 | faanui
# Processing Record 38 of set 3 | kigoma
# Processing Record 39 of set 3 | new norfolk
# Processing Record 40 of set 3 | provideniya
# Processing Record 41 of set 3 | krasnoselkup
# Processing Record 42 of set 3 | castro
# Processing Record 43 of set 3 | narsaq
# Processing Record 44 of set 3 | baruun-urt
# Processing Record 45 of set 3 | puerto escondido
# Processing Record 46 of set 3 | boyuibe
# Processing Record 47 of set 3 | kaliua
# Processing Record 48 of set 3 | liwale
# Processing Record 49 of set 3 | khatanga
# City not found. Skipping...
# Processing Record 1 of set 4 | ajdabiya
# Processing Record 2 of set 4 | rorvik
# Processing Record 3 of set 4 | shirokiy
# Processing Record 4 of set 4 | ancud
# Processing Record 5 of set 4 | torbay
# Processing Record 6 of set 4 | hobyo
# Processing Record 7 of set 4 | hofn
# Processing Record 8 of set 4 | mwinilunga
# City not found. Skipping...
# Processing Record 10 of set 4 | lufilufi
# Processing Record 11 of set 4 | jardim
# Processing Record 12 of set 4 | tagusao
# Processing Record 13 of set 4 | arcata
# Processing Record 14 of set 4 | hovd
# Processing Record 15 of set 4 | houma
# Processing Record 16 of set 4 | alofi
# Processing Record 17 of set 4 | petropavlovsk-kamchatskiy
# Processing Record 18 of set 4 | goderich
# Processing Record 19 of set 4 | yellowknife
# City not found. Skipping...
# Processing Record 21 of set 4 | pangai
# Processing Record 22 of set 4 | marawi
# Processing Record 23 of set 4 | adolfo lopez mateos
# Processing Record 24 of set 4 | lagoa
# Processing Record 25 of set 4 | hamilton
# Processing Record 26 of set 4 | busselton
# Processing Record 27 of set 4 | laguna
# Processing Record 28 of set 4 | sinnamary
# Processing Record 29 of set 4 | qaanaaq
# Processing Record 30 of set 4 | pevek
# City not found. Skipping...
# Processing Record 32 of set 4 | airai
# Processing Record 33 of set 4 | nanortalik
# Processing Record 34 of set 4 | nema
# Processing Record 35 of set 4 | cockburn town
# Processing Record 36 of set 4 | zhanaozen
# Processing Record 37 of set 4 | henties bay
# Processing Record 38 of set 4 | deputatskiy
# Processing Record 39 of set 4 | college
# City not found. Skipping...
# Processing Record 41 of set 4 | katakwi
# Processing Record 42 of set 4 | mount gambier
# Processing Record 43 of set 4 | egvekinot
# Processing Record 44 of set 4 | iranshahr
# Processing Record 45 of set 4 | ponta do sol
# Processing Record 46 of set 4 | chokurdakh
# Processing Record 47 of set 4 | tilichiki
# Processing Record 48 of set 4 | camana
# Processing Record 49 of set 4 | kaoma
# Processing Record 50 of set 4 | yershov
# City not found. Skipping...
# Processing Record 2 of set 5 | saint george
# Processing Record 3 of set 5 | hasaki
# Processing Record 4 of set 5 | okhotsk
# Processing Record 5 of set 5 | severo-kurilsk
# Processing Record 6 of set 5 | port alfred
# Processing Record 7 of set 5 | cabo san lucas
# Processing Record 8 of set 5 | srednekolymsk
# Processing Record 9 of set 5 | celestun
# Processing Record 10 of set 5 | maamba
# Processing Record 11 of set 5 | mecca
# Processing Record 12 of set 5 | bubaque
# Processing Record 13 of set 5 | birao
# Processing Record 14 of set 5 | omsukchan
# Processing Record 15 of set 5 | komsomolskiy
# Processing Record 16 of set 5 | burns lake
# Processing Record 17 of set 5 | mogadishu
# Processing Record 18 of set 5 | zhangjiakou
# Processing Record 19 of set 5 | mumbwa
# Processing Record 20 of set 5 | staryy nadym
# Processing Record 21 of set 5 | pangody
# Processing Record 22 of set 5 | humberto de campos
# Processing Record 23 of set 5 | tokmak
# Processing Record 24 of set 5 | lagos
# Processing Record 25 of set 5 | geraldton
# Processing Record 26 of set 5 | kharp
# Processing Record 27 of set 5 | muros
# Processing Record 28 of set 5 | raduzhnyy
# Processing Record 29 of set 5 | ribeira grande
# Processing Record 30 of set 5 | kamenka
# Processing Record 31 of set 5 | puerto madryn
# Processing Record 32 of set 5 | amapa
# Processing Record 33 of set 5 | sechura
# Processing Record 34 of set 5 | plettenberg bay
# Processing Record 35 of set 5 | saldanha
# Processing Record 36 of set 5 | puerto ayora
# Processing Record 37 of set 5 | manokwari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of set 5 | bethel
# Processing Record 41 of set 5 | ladson
# Processing Record 42 of set 5 | fairbanks
# Processing Record 43 of set 5 | lunel
# Processing Record 44 of set 5 | snezhnogorsk
# Processing Record 45 of set 5 | cap-aux-meules
# Processing Record 46 of set 5 | chernyshevskiy
# Processing Record 47 of set 5 | kahului
# Processing Record 48 of set 5 | skjervoy
# Processing Record 49 of set 5 | luderitz
# Processing Record 50 of set 5 | coihaique
# Processing Record 1 of set 6 | dombarovskiy
# Processing Record 2 of set 6 | tiksi
# Processing Record 3 of set 6 | nishihara
# Processing Record 4 of set 6 | bakchar
# Processing Record 5 of set 6 | nome
# Processing Record 6 of set 6 | mandera
# Processing Record 7 of set 6 | matveyevka
# Processing Record 8 of set 6 | asau
# Processing Record 9 of set 6 | pakxe
# Processing Record 10 of set 6 | kavieng
# Processing Record 11 of set 6 | mikhaylovka
# Processing Record 12 of set 6 | ravar
# Processing Record 13 of set 6 | san cristobal
# Processing Record 14 of set 6 | makakilo city
# City not found. Skipping...
# Processing Record 16 of set 6 | peterhead
# Processing Record 17 of set 6 | arawa
# Processing Record 18 of set 6 | kaeo
# Processing Record 19 of set 6 | margate
# Processing Record 20 of set 6 | erzin
# Processing Record 21 of set 6 | twin falls
# City not found. Skipping...
# Processing Record 23 of set 6 | yining
# Processing Record 24 of set 6 | cayenne
# Processing Record 25 of set 6 | great falls
# City not found. Skipping...
# Processing Record 27 of set 6 | biak
# Processing Record 28 of set 6 | qui nhon
# Processing Record 29 of set 6 | kismayo
# Processing Record 30 of set 6 | yemtsa
# Processing Record 31 of set 6 | manta
# Processing Record 32 of set 6 | oak harbor
# Processing Record 33 of set 6 | barrow
# Processing Record 34 of set 6 | chistogorskiy
# Processing Record 35 of set 6 | mindelo
# Processing Record 36 of set 6 | nichinan
# Processing Record 37 of set 6 | brookings
# Processing Record 38 of set 6 | totness
# Processing Record 39 of set 6 | awbari
# Processing Record 40 of set 6 | aswan
# Processing Record 41 of set 6 | najran
# Processing Record 42 of set 6 | roma
# Processing Record 43 of set 6 | santa isabel do rio negro
# City not found. Skipping...
# Processing Record 45 of set 6 | muskogee
# Processing Record 46 of set 6 | roald
# Processing Record 47 of set 6 | kloulklubed
# Processing Record 48 of set 6 | karangasem
# Processing Record 49 of set 6 | kaitangata
# Processing Record 50 of set 6 | verkhnevilyuysk
# City not found. Skipping...
# Processing Record 2 of set 7 | springdale
# Processing Record 3 of set 7 | fairview
# Processing Record 4 of set 7 | bodden town
# Processing Record 5 of set 7 | zaysan
# Processing Record 6 of set 7 | leshukonskoye
# Processing Record 7 of set 7 | zambezi
# City not found. Skipping...
# Processing Record 9 of set 7 | victor harbor
# Processing Record 10 of set 7 | san antonio
# Processing Record 11 of set 7 | gagra
# Processing Record 12 of set 7 | sattahip
# Processing Record 13 of set 7 | weihai
# Processing Record 14 of set 7 | sarahan
# Processing Record 15 of set 7 | shiraz
# Processing Record 16 of set 7 | dzheyrakh
# Processing Record 17 of set 7 | katobu
# Processing Record 18 of set 7 | dzaoudzi
# Processing Record 19 of set 7 | la estancia
# Processing Record 20 of set 7 | seoul
# Processing Record 21 of set 7 | ulladulla
# Processing Record 22 of set 7 | poronaysk
# Processing Record 23 of set 7 | port macquarie
# Processing Record 24 of set 7 | bathsheba
# Processing Record 25 of set 7 | mount isa
# Processing Record 26 of set 7 | skibbereen
# Processing Record 27 of set 7 | walvis bay
# Processing Record 28 of set 7 | skelleftea
# Processing Record 29 of set 7 | aquiraz
# Processing Record 30 of set 7 | ocos
# Processing Record 31 of set 7 | le port
# Processing Record 32 of set 7 | nabire
# Processing Record 33 of set 7 | lerwick
# Processing Record 34 of set 7 | raudeberg
# City not found. Skipping...
# Processing Record 36 of set 7 | madang
# Processing Record 37 of set 7 | atherton
# Processing Record 38 of set 7 | vila nova de milfontes
# Processing Record 39 of set 7 | ciudad bolivar
# Processing Record 40 of set 7 | yar-sale
# Processing Record 41 of set 7 | padang
# Processing Record 42 of set 7 | igarka
# Processing Record 43 of set 7 | talnakh
# City not found. Skipping...
# Processing Record 45 of set 7 | ureki
# Processing Record 46 of set 7 | maragogi
# Processing Record 47 of set 7 | paamiut
# Processing Record 48 of set 7 | atar
# Processing Record 49 of set 7 | quatre cocos
# City not found. Skipping...
# Processing Record 1 of set 8 | kathmandu
# Processing Record 2 of set 8 | am timan
# City not found. Skipping...
# Processing Record 4 of set 8 | sorong
# City not found. Skipping...
# Processing Record 6 of set 8 | pokhara
# Processing Record 7 of set 8 | hailun
# Processing Record 8 of set 8 | laishevo
# Processing Record 9 of set 8 | nuevo ideal
# Processing Record 10 of set 8 | bima
# Processing Record 11 of set 8 | worthington
# Processing Record 12 of set 8 | vila velha
# Processing Record 13 of set 8 | kodiak
# Processing Record 14 of set 8 | sao filipe
# Processing Record 15 of set 8 | ko samui
# Processing Record 16 of set 8 | isakly
# Processing Record 17 of set 8 | ilave
# City not found. Skipping...
# Processing Record 19 of set 8 | lavrentiya
# Processing Record 20 of set 8 | wadi musa
# Processing Record 21 of set 8 | kristinehamn
# Processing Record 22 of set 8 | high rock
# Processing Record 23 of set 8 | la ronge
# Processing Record 24 of set 8 | zhob
# Processing Record 25 of set 8 | ahipara
# City not found. Skipping...
# Processing Record 27 of set 8 | perieti
# Processing Record 28 of set 8 | jaguarao
# Processing Record 29 of set 8 | parli
# Processing Record 30 of set 8 | souillac
# Processing Record 31 of set 8 | balakhninskiy
# Processing Record 32 of set 8 | zhuanghe
# Processing Record 33 of set 8 | audincourt
# Processing Record 34 of set 8 | cam ranh
# Processing Record 35 of set 8 | wajima
# Processing Record 36 of set 8 | cap malheureux
# Processing Record 37 of set 8 | progreso
# Processing Record 38 of set 8 | buin
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 of set 8 | floresta
# Processing Record 42 of set 8 | yangjiang
# Processing Record 43 of set 8 | kourou
# City not found. Skipping...
# Processing Record 45 of set 8 | vanimo
# Processing Record 46 of set 8 | aldan
# Processing Record 47 of set 8 | del rio
# City not found. Skipping...
# Processing Record 49 of set 8 | tadine
# Processing Record 50 of set 8 | nong chik
# Processing Record 1 of set 9 | ukiah
# City not found. Skipping...
# Processing Record 3 of set 9 | tura
# Processing Record 4 of set 9 | alice town
# Processing Record 5 of set 9 | broken hill
# Processing Record 6 of set 9 | sorland
# Processing Record 7 of set 9 | ust-tsilma
# Processing Record 8 of set 9 | arica
# City not found. Skipping...
# Processing Record 10 of set 9 | las vegas
# Processing Record 11 of set 9 | naruto
# Processing Record 12 of set 9 | tutoia
# Processing Record 13 of set 9 | nantucket
# Processing Record 14 of set 9 | barranca
# Processing Record 15 of set 9 | dongning
# Processing Record 16 of set 9 | abaete
# Processing Record 17 of set 9 | superior
# Processing Record 18 of set 9 | codrington
# Processing Record 19 of set 9 | luanda
# Processing Record 20 of set 9 | arman
# Processing Record 21 of set 9 | mizdah
# Processing Record 22 of set 9 | melfort
# Processing Record 23 of set 9 | ust-kulom
# Processing Record 24 of set 9 | adeje
# Processing Record 25 of set 9 | gimli
# Processing Record 26 of set 9 | san quintin
# Processing Record 27 of set 9 | terpinnya
# Processing Record 28 of set 9 | santa maria
# Processing Record 29 of set 9 | ligayan
# Processing Record 30 of set 9 | sayan
# Processing Record 31 of set 9 | whitehorse
# Processing Record 32 of set 9 | botwood
# Processing Record 33 of set 9 | moju
# Processing Record 34 of set 9 | itiuba
# Processing Record 35 of set 9 | magway
# Processing Record 36 of set 9 | samarai
# Processing Record 37 of set 9 | wanlaweyn
# Processing Record 38 of set 9 | el alto
# Processing Record 39 of set 9 | khandyga
# Processing Record 40 of set 9 | omboue
# Processing Record 41 of set 9 | vladeni
# Processing Record 42 of set 9 | aklavik
# Processing Record 43 of set 9 | beyneu
# City not found. Skipping...
# Processing Record 45 of set 9 | phalodi
# Processing Record 46 of set 9 | atambua
# Processing Record 47 of set 9 | rocha
# Processing Record 48 of set 9 | skjern
# Processing Record 49 of set 9 | cua
# Processing Record 50 of set 9 | raga
# Processing Record 1 of set 10 | ilhabela
# Processing Record 2 of set 10 | waddan
# Processing Record 3 of set 10 | suntar
# Processing Record 4 of set 10 | alta floresta
# Processing Record 5 of set 10 | pemangkat
# Processing Record 6 of set 10 | vilyuysk
# Processing Record 7 of set 10 | saint-georges
# Processing Record 8 of set 10 | shimoda
# Processing Record 9 of set 10 | sampit
# Processing Record 10 of set 10 | tambura
# Processing Record 11 of set 10 | grenville
# Processing Record 12 of set 10 | honiara
# Processing Record 13 of set 10 | tougan
# Processing Record 14 of set 10 | salalah
# Processing Record 15 of set 10 | den helder
# Processing Record 16 of set 10 | luang prabang
# Processing Record 17 of set 10 | svetlogorsk
# Processing Record 18 of set 10 | aksu
# Processing Record 19 of set 10 | coquimbo
# Processing Record 20 of set 10 | morehead
# Processing Record 21 of set 10 | kokstad
# Processing Record 22 of set 10 | visby
# Processing Record 23 of set 10 | klyuchi
# Processing Record 24 of set 10 | qarchi gak
# Processing Record 25 of set 10 | kruisfontein
# Processing Record 26 of set 10 | benjamin aceval
# Processing Record 27 of set 10 | vila franca do campo
# Processing Record 28 of set 10 | turukhansk
# Processing Record 29 of set 10 | yambio
# Processing Record 30 of set 10 | kampot
# Processing Record 31 of set 10 | chapais
# Processing Record 32 of set 10 | luba
# Processing Record 33 of set 10 | santa vitoria do palmar
# Processing Record 34 of set 10 | sainte-suzanne
# Processing Record 35 of set 10 | fall river
# Processing Record 36 of set 10 | kapit
# Processing Record 37 of set 10 | dieppe
# Processing Record 38 of set 10 | kurilsk
# Processing Record 39 of set 10 | darayya
# Processing Record 40 of set 10 | pavlodar
# Processing Record 41 of set 10 | pimentel
# Processing Record 42 of set 10 | galautas
# Processing Record 43 of set 10 | farafangana
# Processing Record 44 of set 10 | guerrero negro
# Processing Record 45 of set 10 | santa cruz
# Processing Record 46 of set 10 | lompoc
# Processing Record 47 of set 10 | yanam
# City not found. Skipping...
# Processing Record 49 of set 10 | konevo
# Processing Record 50 of set 10 | baishishan
# Processing Record 1 of set 11 | cuamba
# Processing Record 2 of set 11 | guamal
# Processing Record 3 of set 11 | yahotyn
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of set 11 | umm lajj
# Processing Record 7 of set 11 | boma
# Processing Record 8 of set 11 | nouadhibou
# Processing Record 9 of set 11 | yabrud
# Processing Record 10 of set 11 | naze
# Processing Record 11 of set 11 | flin flon
# Processing Record 12 of set 11 | umea
# Processing Record 13 of set 11 | la maddalena
# Processing Record 14 of set 11 | port blair
# Processing Record 15 of set 11 | salinopolis
# Processing Record 16 of set 11 | fayetteville
# Processing Record 17 of set 11 | korla
# Processing Record 18 of set 11 | kysyl-syr
# Processing Record 19 of set 11 | tautira
# Processing Record 20 of set 11 | talara
# Processing Record 21 of set 11 | emba
# Processing Record 22 of set 11 | sedkyrkeshch
# Processing Record 23 of set 11 | benin
# Processing Record 24 of set 11 | kenai
# Processing Record 25 of set 11 | san angelo
# Processing Record 26 of set 11 | elko
# Processing Record 27 of set 11 | hargeysa
# Processing Record 28 of set 11 | gien
# Processing Record 29 of set 11 | marsh harbour
# Processing Record 30 of set 11 | panaba
# Processing Record 31 of set 11 | niksar
# Processing Record 32 of set 11 | phalaborwa
# Processing Record 33 of set 11 | cidreira
# Processing Record 34 of set 11 | tommot
# Processing Record 35 of set 11 | novobirilyussy
# Processing Record 36 of set 11 | adrar
# Processing Record 37 of set 11 | placerville
# Processing Record 38 of set 11 | karatau
# City not found. Skipping...
# Processing Record 40 of set 11 | the pas
# Processing Record 41 of set 11 | zorritos
# Processing Record 42 of set 11 | bat yam
# Processing Record 43 of set 11 | mnogovershinnyy
# City not found. Skipping...
# Processing Record 45 of set 11 | port hardy
# Processing Record 46 of set 11 | richards bay
# Processing Record 47 of set 11 | tallahassee
# Processing Record 48 of set 11 | katsuura
# Processing Record 49 of set 11 | miri
# Processing Record 50 of set 11 | ialibu
# Processing Record 1 of set 12 | san jose de guanipa
# Processing Record 2 of set 12 | westport
# Processing Record 3 of set 12 | scarborough
# Processing Record 4 of set 12 | abu samrah
# City not found. Skipping...
# Processing Record 6 of set 12 | itoman
# Processing Record 7 of set 12 | bilma
# Processing Record 8 of set 12 | mandalgovi
# Processing Record 9 of set 12 | jodhpur
# Processing Record 10 of set 12 | iracoubo
# Processing Record 11 of set 12 | bure
# Processing Record 12 of set 12 | la asuncion
# Processing Record 13 of set 12 | lorengau
# Processing Record 14 of set 12 | portland
# Processing Record 15 of set 12 | bhuj
# Processing Record 16 of set 12 | idaho falls
# Processing Record 17 of set 12 | gladstone
# Processing Record 18 of set 12 | diffa
# City not found. Skipping...
# Processing Record 20 of set 12 | mahajanga
# Processing Record 21 of set 12 | akureyri
# Processing Record 22 of set 12 | xuddur
# Processing Record 23 of set 12 | port-gentil
# Processing Record 24 of set 12 | zheleznodorozhnyy
# Processing Record 25 of set 12 | palmas bellas
# Processing Record 26 of set 12 | haines junction
# Processing Record 27 of set 12 | chute-aux-outardes
# Processing Record 28 of set 12 | mahibadhoo
# Processing Record 29 of set 12 | mitsamiouli
# Processing Record 30 of set 12 | bonavista
# Processing Record 31 of set 12 | nalut
# Processing Record 32 of set 12 | yerbogachen
# Processing Record 33 of set 12 | tamayo
# Processing Record 34 of set 12 | san jeronimo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of set 12 | olga
# Processing Record 38 of set 12 | dorogino
# Processing Record 39 of set 12 | ust-koksa
# Processing Record 40 of set 12 | prainha
# Processing Record 41 of set 12 | lodja
# Processing Record 42 of set 12 | arlit
# Processing Record 43 of set 12 | domat
# Processing Record 44 of set 12 | vostok
# Processing Record 45 of set 12 | sur
# Processing Record 46 of set 12 | tarakan
# Processing Record 47 of set 12 | mao
# City not found. Skipping...
# Processing Record 49 of set 12 | puerto rondon
# Processing Record 50 of set 12 | mahina
# Processing Record 1 of set 13 | maniitsoq
# Processing Record 2 of set 13 | makungu
# Processing Record 3 of set 13 | ritchie
# Processing Record 4 of set 13 | kirakira
# Processing Record 5 of set 13 | zhicheng
# Processing Record 6 of set 13 | tekkali
# Processing Record 7 of set 13 | el tigre
# Processing Record 8 of set 13 | tuburan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of set 13 | santa cruz de tenerife
# City not found. Skipping...
# Processing Record 13 of set 13 | gold coast
# City not found. Skipping...
# Processing Record 15 of set 13 | oda
# Processing Record 16 of set 13 | fort nelson
# Processing Record 17 of set 13 | buritizeiro
# Processing Record 18 of set 13 | opelousas
# Processing Record 19 of set 13 | karwar
# Processing Record 20 of set 13 | saint-pierre

# %%
#Create dictionary with lists 
Weather_dict={
    "City":City_name,
    "Lat":Lat,
    "Lng":Lng,
    "Max Temp":Max_Tmp,
    "Humidity":Humidity,
    "Cloudiness":Cloudiness,
    "Wind Speed":Wind_Spd,
    "Country":Country,
    "Date":Date
}

#Create Data Frame and display
weather_df=pd.DataFrame(Weather_dict)
weather_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Isla Vista  34.4133 -119.8610     55.00        81           1
# 1       Hithadhoo  -0.6000   73.0833     83.57        78          95
# 2            Tefé  -3.3542  -64.7114     70.66        98          99
# 3        Tasiilaq  65.6145  -37.6368     12.20        73           0
# 4           Kutum  14.2000   24.6667     77.16        17           0
# ..            ...      ...       ...       ...       ...         ...
# 561   Fort Nelson  58.8053 -122.7002      1.40        85          40
# 562   Buritizeiro -17.3511  -44.9622     71.71        88          80
# 563     Opelousas  30.5335  -92.0815     44.01        75          75
# 564        Karwar  14.8000   74.1333     83.61        67          56
# 565  Saint-Pierre -21.3393   55.4781     86.00        58           0
#
#      Wind Speed Country        Date
# 0          5.68      US  1610099503
# 1         18.48      MV  1610099532
# 2          2.28      BR  1610099532
# 3         28.77      GL  1610099533
# 4         22.59      SD  1610099533
# ..          ...     ...         ...
# 561        2.30      CA  1610099582
# 562        3.04      BR  1610099440
# 563        6.91      US  1610099582
# 564        7.09      IN  1610099582
# 565       26.46      RE  1610099582
#
# [566 rows x 9 columns]

# %%
#display descriptive statistics
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  566.000000  566.000000  566.000000  566.000000  566.000000  566.000000
# mean    20.536837   13.549172   50.021784   72.747350   56.787986    8.309152
# std     32.585799   88.979751   32.321461   21.542749   39.956050    5.809425
# min    -54.800000 -179.166700  -43.440000   10.000000    0.000000    0.220000
# 25%     -4.801975  -65.033675   30.200000   65.000000    9.000000    3.702500
# 50%     24.490450   20.617750   60.835000   78.000000   75.000000    6.910000
# 75%     47.495975   86.012875   77.000000   88.000000   92.000000   11.500000
# max     78.218600  173.783300   98.650000  100.000000  100.000000   32.210000
#
#                Date
# count  5.660000e+02
# mean   1.610100e+09
# std    5.835002e+01
# min    1.610099e+09
# 25%    1.610100e+09
# 50%    1.610100e+09
# 75%    1.610100e+09
# max    1.610100e+09

# %%
#export data frame to csv file
weather_df.to_csv(output_data_file, index=False)

# %%
#filter cities with humidity bigger than 100
filt=(weather_df['Humidity']>100)
weather_df[filt]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#filter cities with humidity of 100
#---I filtered Humidity==100 just for practice
filt=(weather_df['Humidity']==100)
weather_df[filt]
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 38                Tacoronte  28.4769  -16.4102     62.01       100
# 89                  Emerald -23.5333  148.1667     71.60       100
# 96                Norrtälje  59.7580   18.7050     36.00       100
# 122          Saint-François  46.4154    3.9054     35.01       100
# 123               Cumbitara   1.6517  -77.5823     57.31       100
# 125                  Kigoma  -4.8769   29.6267     68.00       100
# 141                  Torbay  47.6666  -52.7314     41.00       100
# 165                   Airai  -8.9266  125.4092     64.51       100
# 220                  Ladson  32.9857  -80.1098     46.40       100
# 251                 Cayenne   4.9333  -52.3333     73.40       100
# 357                  Kourou   5.1552  -52.6478     73.40       100
# 424              Den Helder  52.9599    4.7593     37.99       100
# 464              Nouadhibou  20.9310  -17.0347     66.20       100
# 468                    Umeå  63.8284   20.2597     19.40       100
# 487                  Niksar  40.5917   36.9517     35.60       100
# 532               Bonavista  48.6499  -53.1147     37.99       100
# 558  Santa Cruz de Tenerife  28.4682  -16.2546     62.01       100
#
#      Cloudiness  Wind Speed Country        Date
# 38           75       26.46      ES  1610099536
# 89           90       19.57      AU  1610099540
# 96           90        8.05      SE  1610099540
# 122          90        2.30      FR  1610099543
# 123         100        1.99      CO  1610099543
# 125          90        3.96      TZ  1610099543
# 141          90        6.91      CA  1610099544
# 165          98        2.10      TL  1610099546
# 220          90        9.22      US  1610099552
# 251          75        2.30      GF  1610099554
# 357          75        2.30      GF  1610099564
# 424          90        3.44      NL  1610099570
# 464          90        4.61      MR  1610099573
# 468          90        4.61      SE  1610099573
# 487          75        6.46      TR  1610099360
# 532          93        2.30      CA  1610099578
# 558          75       26.46      ES  1610099529

# %%
#  Get the indices of cities that have humidity over 100%.
#---I filtered Humidity==100 just for practice
equal_100=weather_df.index[filt]
equal_100=equal_100.tolist()
equal_100
# Out:
# [38,
#  89,
#  96,
#  122,
#  123,
#  125,
#  141,
#  165,
#  220,
#  251,
#  357,
#  424,
#  464,
#  468,
#  487,
#  532,
#  558]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#---I filtered Humidity==100 just for practice
Cleaned_weather_df=weather_df.drop(equal_100)

# %%
# I checked that all indexes with Humidity==100 were dropped
filt=(Cleaned_weather_df['Humidity']==100)
Cleaned_weather_df[filt]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Create a new column to display date with a different format
#---I filtered Humidity==100 just for practice
Cleaned_weather_df['Date_only']=pd.to_datetime(Cleaned_weather_df['Date'],unit='s')
Cleaned_weather_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Isla Vista  34.4133 -119.8610     55.00        81           1
# 1       Hithadhoo  -0.6000   73.0833     83.57        78          95
# 2            Tefé  -3.3542  -64.7114     70.66        98          99
# 3        Tasiilaq  65.6145  -37.6368     12.20        73           0
# 4           Kutum  14.2000   24.6667     77.16        17           0
# ..            ...      ...       ...       ...       ...         ...
# 561   Fort Nelson  58.8053 -122.7002      1.40        85          40
# 562   Buritizeiro -17.3511  -44.9622     71.71        88          80
# 563     Opelousas  30.5335  -92.0815     44.01        75          75
# 564        Karwar  14.8000   74.1333     83.61        67          56
# 565  Saint-Pierre -21.3393   55.4781     86.00        58           0
#
#      Wind Speed Country        Date           Date_only
# 0          5.68      US  1610099503 2021-01-08 09:51:43
# 1         18.48      MV  1610099532 2021-01-08 09:52:12
# 2          2.28      BR  1610099532 2021-01-08 09:52:12
# 3         28.77      GL  1610099533 2021-01-08 09:52:13
# 4         22.59      SD  1610099533 2021-01-08 09:52:13
# ..          ...     ...         ...                 ...
# 561        2.30      CA  1610099582 2021-01-08 09:53:02
# 562        3.04      BR  1610099440 2021-01-08 09:50:40
# 563        6.91      US  1610099582 2021-01-08 09:53:02
# 564        7.09      IN  1610099582 2021-01-08 09:53:02
# 565       26.46      RE  1610099582 2021-01-08 09:53:02
#
# [549 rows x 10 columns]

# %%
#Get the date
Date=Cleaned_weather_df['Date_only'].values[0]
Date=str(Date)
Date=Date[0:10]
print(Date)
# Out:
# 2021-01-08

# %%
#Scatter Plot Latitud vs Max Temp
x_values = weather_df['Lat']
y_values = weather_df['Max Temp']
plt.scatter(x_values,y_values, edgecolors='black')
plt.xlabel('Latitud')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs Max Temperature('+Date+')')
plt.grid()
plt.show()

# %%
#Scatter Plot Latitud vs Cloudiness
x_values = weather_df['Lat']
y_values = weather_df['Cloudiness']
plt.scatter(x_values,y_values, edgecolors='black')
plt.xlabel('Latitud')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs Cloudiness('+Date+')')
plt.grid()
plt.show()

# %%
#Scatter Plot Latitud vs wind Speed
x_values = weather_df['Lat']
y_values = weather_df['Wind Speed']
plt.scatter(x_values,y_values, edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs Wind Speed(mph) ('+Date+')')
plt.grid()
plt.show()

# %%
#Get all cities of the northern hemisphere
filt=(weather_df['Lat']>0)
North_Hemisphere_df=weather_df[filt]
North_Hemisphere_df
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0                Isla Vista  34.4133 -119.8610     55.00        81
# 3                  Tasiilaq  65.6145  -37.6368     12.20        73
# 4                     Kutum  14.2000   24.6667     77.16        17
# 5                    Dwārka  22.2394   68.9678     75.74        31
# 6                 Jamestown  42.0970  -79.2353     24.01        93
# ..                      ...      ...       ...       ...       ...
# 558  Santa Cruz de Tenerife  28.4682  -16.2546     62.01       100
# 560              Ōdachō-ōda  35.1833  132.5000     28.40        59
# 561             Fort Nelson  58.8053 -122.7002      1.40        85
# 563               Opelousas  30.5335  -92.0815     44.01        75
# 564                  Karwar  14.8000   74.1333     83.61        67
#
#      Cloudiness  Wind Speed Country        Date
# 0             1        5.68      US  1610099503
# 3             0       28.77      GL  1610099533
# 4             0       22.59      SD  1610099533
# 5             0       15.88      IN  1610099533
# 6            90        4.61      US  1610098917
# ..          ...         ...     ...         ...
# 558          75       26.46      ES  1610099529
# 560          75       13.80      JP  1610099581
# 561          40        2.30      CA  1610099582
# 563          75        6.91      US  1610099582
# 564          56        7.09      IN  1610099582
#
# [393 rows x 9 columns]

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = North_Hemisphere_df['Lat']
y_values = North_Hemisphere_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp(F)')
plt.title('Northern Hemisphere - City Latitud vs Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7594302642867987

# %%
#Get all cities of the southern hemisphere
filt=(weather_df['Lat']<0)
South_Hemisphere_df=weather_df[filt]
South_Hemisphere_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1       Hithadhoo  -0.6000   73.0833     83.57        78          95
# 2            Tefé  -3.3542  -64.7114     70.66        98          99
# 7         Máncora  -4.1078  -81.0475     73.29        72          90
# 10   Punta Arenas -53.1500  -70.9167     46.40        87          90
# 11      Cape Town -33.9258   18.4232     77.00        50           0
# ..            ...      ...       ...       ...       ...         ...
# 552       Ritchie -29.0380   24.6028     80.60        61          40
# 553      Kirakira -10.4544  161.9205     76.80        88         100
# 559    Gold Coast -28.0000  153.4333     68.00        88          90
# 562   Buritizeiro -17.3511  -44.9622     71.71        88          80
# 565  Saint-Pierre -21.3393   55.4781     86.00        58           0
#
#      Wind Speed Country        Date
# 1         18.48      MV  1610099532
# 2          2.28      BR  1610099532
# 7          6.80      PE  1610099533
# 10        12.66      CL  1610099533
# 11        23.02      ZA  1610099533
# ..          ...     ...         ...
# 552        6.91      ZA  1610099581
# 553       12.95      SB  1610099581
# 559        9.22      AU  1610099571
# 562        3.04      BR  1610099440
# 565       26.46      RE  1610099582
#
# [173 rows x 9 columns]

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = South_Hemisphere_df['Lat']
y_values = South_Hemisphere_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp(F)')
plt.title('Southern Hemisphere - City Latitud vs Max Temp(F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.2229555901479699

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = North_Hemisphere_df['Lat']
y_values = North_Hemisphere_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitud')
plt.ylabel('Humidity(%)')
plt.title('Northern Hemisphere - City Latitud vs Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.1837918731995479

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = South_Hemisphere_df['Lat']
y_values = South_Hemisphere_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitud')
plt.ylabel('Humidity(%)')
plt.title('Southern Hemisphere - City Latitud vs Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.09296382785639606

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = North_Hemisphere_df['Lat']
y_values = North_Hemisphere_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitud')
plt.ylabel('Cloudiness(%)')
plt.title('Northern Hemisphere - City Latitud vs Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.07095393762131208

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = South_Hemisphere_df['Lat']
y_values = South_Hemisphere_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitud')
plt.ylabel('Cloudiness(%)')
plt.title('Southern Hemisphere - City Latitud vs Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.1329726084846479

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = North_Hemisphere_df['Lat']
y_values = North_Hemisphere_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitud')
plt.ylabel('Wind Speed(mph)')
plt.title('Northern Hemisphere - City Latitud vs Wind Speed(mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.008243548565294577

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = South_Hemisphere_df['Lat']
y_values = South_Hemisphere_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitud')
plt.ylabel('Wind Speed(mph)')
plt.title('Southern Hemisphere - City Latitud vs Wind Speed(mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.024657793260096834
